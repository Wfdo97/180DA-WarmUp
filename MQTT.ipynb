# %%
# !pip install paho-mqtt
# Out:
# Collecting paho-mqtt
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      ---------------------------------------- 0.0/99.4 kB ? eta -:--:--
#      ---------------------------------------- 99.4/99.4 kB 5.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: paho-mqtt
#   Building wheel for paho-mqtt (pyproject.toml): started
#   Building wheel for paho-mqtt (pyproject.toml): finished with status 'done'
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=65647 sha256=bb688fad0dad5551d0157b74095f0c157cc51fe6b861738889b1f3568178edb4
#   Stored in directory: c:\users\17147\appdata\local\pip\cache\wheels\0f\90\29\db29bb8ddc98ec5f2363b959130c9ddbcf5cfdb4a00b6184dd
# Successfully built paho-mqtt
# Installing collected packages: paho-mqtt
# Successfully installed paho-mqtt-1.6.1
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Subscriber

# %%
import paho.mqtt.client as mqtt

# 0. define callbacks - functions that run when events happen.
# The callback for when the client receives a CONNACK response from the server.
def on_connect(client, userdata, flags, rc):
    print("Connection returned result: "+str(rc))
    # Subscribing in on_connect() means that if we lose the connection and
    # reconnect then subscriptions will be renewed.
    client.subscribe("ece180d/test", qos=1)

# The callback of the client when it disconnects.
def on_disconnect(client, userdata, rc):
    if rc != 0:
        print('Unexpected Disconnect')
    else:
        print('Expected Disconnect')

# The default message callback.
# (you can create separate callbacks per subscribed topic)
def on_message(client, userdata, message):
    print('Received message: "' + str(message.payload) + '" on topic "' +
        message.topic + '" with QoS ' + str(message.qos))

# 1. create a client instance.
client = mqtt.Client()
# add additional client options (security, certifications, etc.)
# many default options should be good to start off.
# add callbacks to client.
client.on_connect = on_connect
client.on_disconnect = on_disconnect
client.on_message = on_message

# 2. connect to a broker using one of the connect*() functions.
client.connect_async('test.mosquitto.org')
# client.connect("mqtt.eclipse.org")

# 3. call one of the loop*() functions to maintain network traffic flow with the broker.
client.loop_start()
# client.loop_forever()

while True:
    pass
# use subscribe() to subscribe to a topic and receive messages.
# use publish() to publish messages to the broker.
# use disconnect() to disconnect from the broker.

client.loop_stop()
client.disconnect()
# Out:
# Connection returned result: 0
# Unexpected Disconnect
# Connection returned result: 0
# Received message: "b'0.09349948033508304'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9939880923665645'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.0936773676098076'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7105637685646012'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5423574487771687'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.21027747767206129'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.41782699213997854'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6014692747684239'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.10721587732256543'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.29607141348110855'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6996540908461334'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8872125679603086'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.004249949552979526'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.49119539679851887'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9771719941875492'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.23638358707353702'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.23458795046967884'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.592567306903121'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.27643562627730167'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7071390363071325'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.14349596541077714'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.811868246630791'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9553330374880775'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8438566981841876'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.23736984809901063'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.0918958122526361'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.24439316322771543'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9454177296230718'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.034701435925215574'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9222662062434298'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.13403158740756427'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4712952705998261'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5478204638164028'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.13498755128943607'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8456602083458756'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1953885109840675'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8450371970695224'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4535268086979831'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8163582874863062'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9377200347563712'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2132746039581358'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.028435744009337793'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9530933950355522'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.34279294106977964'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8108024653768711'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2703120604452237'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9712780242740509'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.15902742846864193'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8598308741176869'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9846761161108909'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5634782771360002'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6291043693525258'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.01440238350324985'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.16899271900062773'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.987694584853537'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8805721630460125'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4088808754699017'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1545166036334995'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8251790821774949'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9972913524583383'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8767212921396392'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.36624232841784343'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4218322825973827'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9506403452602948'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9050584760615326'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5410626624786496'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.004449571054973123'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.27357149280418813'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5764027930982725'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7660931598747441'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2895517917102082'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5935674867970968'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9443553918819843'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.731855810390941'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4261313201645699'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7933177150228583'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.21832231441189331'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7058673115814083'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8142451884139846'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8682903126948948'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5674461806884589'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.46037350242645936'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4146467215362254'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9194965694968222'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9925083681429727'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.13784411589424117'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8966689894485389'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.21830301185268774'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8700952151340158'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.594380341760784'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8041999986666836'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2379308591728303'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.069568503437766'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.02540699937115909'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5965743609335311'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.3121261914256649'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7544687704162596'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.19286306193664338'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.32769996151702574'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4942236337565994'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7952558494457072'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7375637765801631'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1938154208543147'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7433345707600787'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.3591927878066047'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2790562109545769'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.47642716568816945'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4969520935222719'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9428220170540111'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9708922693536859'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8554293138963545'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6487317025576433'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2569434338610629'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1843552906137924'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2766919210831319'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.11796348910741983'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2798325272969363'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7721949303520181'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.07775101720337818'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.3921653981493286'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7313390789031848'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.34649923181585496'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9801008499182164'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7440498618295519'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.3610392330271224'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2199677261427737'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5189313693330118'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8406169889705088'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4245681179612628'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.13082655373649277'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8680635653927354'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.043135217912461776'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6442292011133733'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.011458872506083684'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8544821758020663'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9629251984826886'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7618917258495025'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5974727784783325'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8514501433042228'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.37769873850152313'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1973253558418585'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.27323942372498833'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.952142948145389'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.21319091338345109'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6789693093365086'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5828742705835547'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.390119240836598'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7117350440057022'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.004377109714074234'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6086310978591161'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7730325519137651'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7610812021246304'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7101606889763837'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7509282208450875'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.28245007173787073'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.87856635086518'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6655766911450045'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7342132881217334'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6360299232330513'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.596123740171599'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7841191263754349'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.23316182969218313'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6143758039639511'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.07202602643226508'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9831150618824352'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5411441815569157'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8195131952685367'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9461177893724011'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6269227128646508'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.46212096111815726'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1841496382372534'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7609497218812226'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5538806751736862'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.9606887993681674'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.10352416191907565'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7903766504509965'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5689438278616942'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6179146796754922'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.040485198804581346'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8365941229712932'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.1396398073257512'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2733393135938632'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7892509108536953'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6768267998824956'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.18069073332440788'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8816387836319433'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.4640530021709751'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7728743219683688'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.2370520172985211'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.012831785163062714'" on topic "ece180d/test" with QoS 1
# Unexpected Disconnect
# Connection returned result: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 42
#      39 # client.loop_forever()
#      41 while True:
# ---> 42     pass
#      43 # use subscribe() to subscribe to a topic and receive messages.
#      44 # use publish() to publish messages to the broker.
#      45 # use disconnect() to disconnect from the broker.
#      47 client.loop_stop()
#
# KeyboardInterrupt:

# %% [markdown]
# # Publisher

# %%
import paho.mqtt.client as mqtt
import numpy as np

# 0. define callbacks - functions that run when events happen.
# The callback for when the client receives a CONNACK response from the server.
def on_connect(client, userdata, flags, rc):
    print("Connection returned result: "+str(rc))
    # Subscribing in on_connect() means that if we lose the connection and
    # reconnect then subscriptions will be renewed.
    # client.subscribe("ece180d/test")

def on_disconnect(client, userdata, rc):
    if rc != 0:
        print('Unexpected Disconnect')
    else:
        print('Expected Disconnect')
    # The default message callback.
    # (won’t be used if only publishing, but can still exist)

def on_message(client, userdata, message):
    print('Received message: "' + str(message.payload) + '" on topic "' +
    message.topic + '" with QoS ' + str(message.qos))
    
# 1. create a client instance.
client = mqtt.Client()

# add additional client options (security, certifications, etc.)
# many default options should be good to start off.
# add callbacks to client.
client.on_connect = on_connect
client.on_disconnect = on_disconnect
client.on_message = on_message

# 2. connect to a broker using one of the connect*() functions.
client.connect_async('test.mosquitto.org')

# 3. call one of the loop*() functions to maintain network traffic flow with the broker.
client.loop_start()

# 4. use subscribe() to subscribe to a topic and receive messages.
# 5. use publish() to publish messages to the broker.
# payload must be a string, bytearray, int, float or None.
for i in range(10):
    client.publish('ece180d/test', float(np.random.random(1)), qos=1)
    
# 6. use disconnect() to disconnect from the broker.
client.loop_stop()
client.disconnect()
# Out:
# C:\Users\17147\AppData\Local\Temp\ipykernel_5544\2606394659.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   client.publish('ece180d/test', float(np.random.random(1)), qos=1)
# Connection returned result: 0
# Received message: "b'0.16342401450281507'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6113821772883724'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.16927443080920623'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.5461672850395227'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.714372594239043'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.8256971871254964'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.07263966404955302'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.421027258111514'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.6273080987286578'" on topic "ece180d/test" with QoS 1
# Received message: "b'0.7421215482475381'" on topic "ece180d/test" with QoS 1
# Expected Disconnect
# 0
